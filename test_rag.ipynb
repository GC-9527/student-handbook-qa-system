# %% [markdown]
# # 学生手册智能问答系统 - 测试 Notebook

# %%
import pandas as pd

df = pd.DataFrame([
    {
        "name": "张三",
        "age": 18,
        "gender": "男",
        "address": "北京",
        "phone": "12345678901"
    },
    {
        "name": "李四",
        "age": 19,
        "gender": "女",
        "address": "上海",
        "phone": "12345678902"
    },
    {
        "name": "王五",
        "age": 20,
        "gender": "男",
    }
])
df
# Out:
#   name  age gender address        phone
# 0   张三   18      男      北京  12345678901
# 1   李四   19      女      上海  12345678902
# 2   王五   20      男     NaN          NaN

# %%
print('Hello World')
